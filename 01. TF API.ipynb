# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
# Create tensoroflow constants

a = tf.constant([[10,20],[30,40]])
b = tf.constant([[50,60],[70,80]])

# %%
a
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[10, 20],
#        [30, 40]], dtype=int32)>

# %%
b
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[50, 60],
#        [70, 80]], dtype=int32)>

# %%
# basic operations

print(a+2)
# Out:
# tf.Tensor(
# [[12 22]
#  [32 42]], shape=(2, 2), dtype=int32)

# %%
print(b+5)
# Out:
# tf.Tensor(
# [[55 65]
#  [75 85]], shape=(2, 2), dtype=int32)

# %%
print(a*2)
# Out:
# tf.Tensor(
# [[20 40]
#  [60 80]], shape=(2, 2), dtype=int32)

# %%
print(b*2)
# Out:
# tf.Tensor(
# [[100 120]
#  [140 160]], shape=(2, 2), dtype=int32)

# %%
print(a*b)
# Out:
# tf.Tensor(
# [[ 500 1200]
#  [2100 3200]], shape=(2, 2), dtype=int32)

# %%
# To perform element wise multiplication use tf.multiply() method.

mul = tf.multiply(a,b)

# %%
mul
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[ 500, 1200],
#        [2100, 3200]], dtype=int32)>

# %%
# dot product

dot_product = tf.matmul(a,b)

# %%
dot_product
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1900, 2200],
#        [4300, 5000]], dtype=int32)>
