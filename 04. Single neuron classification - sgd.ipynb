# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/DL /diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df["BloodPressure"].value_counts().sort_values()
# Out:
# 122     1
# 40      1
# 38      1
# 24      1
# 114     1
# 61      1
# 102     1
# 95      1
# 104     2
# 108     2
# 55      2
# 46      2
# 30      2
# 106     3
# 100     3
# 110     3
# 98      3
# 96      4
# 44      4
# 48      5
# 85      6
# 94      6
# 65      7
# 75      8
# 92      8
# 54     11
# 52     11
# 56     12
# 50     13
# 58     21
# 86     21
# 90     22
# 84     23
# 88     25
# 82     30
# 66     30
# 62     34
# 0      35
# 60     37
# 76     39
# 80     40
# 64     43
# 72     44
# 78     45
# 68     45
# 74     52
# 70     57
# Name: BloodPressure, dtype: int64

# %%
df["SkinThickness"].value_counts().sort_values()
# Out:
# 99      1
# 60      1
# 51      1
# 63      1
# 56      1
# 8       2
# 7       2
# 52      2
# 54      2
# 49      3
# 50      3
# 47      4
# 48      4
# 10      5
# 44      5
# 45      6
# 43      6
# 11      6
# 16      6
# 14      6
# 12      7
# 38      7
# 46      8
# 34      8
# 21     10
# 13     11
# 42     11
# 24     12
# 20     13
# 17     14
# 15     14
# 36     14
# 41     15
# 35     15
# 25     16
# 40     16
# 22     16
# 26     16
# 37     16
# 29     17
# 39     18
# 19     18
# 31     19
# 28     20
# 18     20
# 33     20
# 23     22
# 27     23
# 30     27
# 32     31
# 0     227
# Name: SkinThickness, dtype: int64

# %%
df["BMI"].value_counts().sort_values()
# Out:
# 42.8     1
# 20.1     1
# 30.3     1
# 30.7     1
# 43.2     1
#         ..
# 33.3    10
# 0.0     11
# 31.2    12
# 31.6    12
# 32.0    13
# Name: BMI, Length: 248, dtype: int64

# %% [markdown]
# <li><b>Here we can observe that the null values is replaced by 0, because how a person can have BMI, skinthickness, BloodPressure, etc as 0 it is not
# possible so we will replace it with some central tendency.</b></li>

# %%
# Replacing 0 by NaN

df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
# Again, getting no. of missing values in each column 

df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
# Filling NaN values 

df['Glucose'].fillna(df['Glucose'].median(), inplace = True)
df['BloodPressure'].fillna(df['BloodPressure'].median(), inplace = True)
df['SkinThickness'].fillna(df['SkinThickness'].median(), inplace = True)
df['Insulin'].fillna(df['Insulin'].median(), inplace = True)
df['BMI'].fillna(df['BMI'].mean(), inplace = True)

# %%
# Checking missing values correctly replaced

df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot = True)

# %%
# Finding pairwise correlation of all columns

df.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.128213  ...  0.544341  0.221898
# Glucose                      0.128213  1.000000  ...  0.266909  0.492782
# BloodPressure                0.208615  0.218937  ...  0.324915  0.165723
# SkinThickness                0.081770  0.192615  ...  0.126107  0.214873
# Insulin                      0.025047  0.419451  ...  0.097101  0.203790
# BMI                          0.021565  0.230862  ...  0.025519  0.311924
# DiabetesPedigreeFunction    -0.033523  0.137327  ...  0.033561  0.173844
# Age                          0.544341  0.266909  ...  1.000000  0.238356
# Outcome                      0.221898  0.492782  ...  0.238356  1.000000
#
# [9 rows x 9 columns]

# %%
# Getting unique values 

df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
  # Finding counts of unique values and sorting it in ascending order

df['Pregnancies'].value_counts().sort_values()
# Out:
# 17      1
# 15      1
# 14      2
# 12      9
# 13     10
# 11     11
# 10     24
# 9      28
# 8      38
# 7      45
# 6      50
# 5      57
# 4      68
# 3      75
# 2     103
# 0     111
# 1     135
# Name: Pregnancies, dtype: int64

# %%
# Grouping predictor variables by target variable

df.groupby("Outcome")[["Pregnancies","Glucose","BloodPressure"]].agg(['max','min','mean'])
# Out:
#         Pregnancies                ... BloodPressure
#                 max min      mean  ...           max   min       mean
# Outcome                            ...
# 0                13   0  3.298000  ...         122.0  24.0  70.920000
# 1                17   0  4.865672  ...         114.0  30.0  75.123134
#
# [2 rows x 9 columns]

# %%
df.groupby("Outcome")[["SkinThickness","Insulin","BMI","Age"]].agg(['max','min','mean'])
# Out:
#         SkinThickness                 Insulin  ...        BMI Age
#                   max  min       mean     max  ...       mean max min       mean
# Outcome                                        ...
# 0                60.0  7.0  27.726000   744.0  ...  30.888434  81  21  31.190000
# 1                99.0  7.0  31.686567   846.0  ...  35.384757  70  21  37.067164
#
# [2 rows x 12 columns]

# %%
# Model
X = df.drop("Outcome",axis = 1)
y = df["Outcome"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (537, 8)

# %%
from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import MinMaxScaler

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train)
X_test_ss = ss.transform(X_test)

#mm = MinMaxScaler()
#X_train_mm = mm.fit_transform(X_train)
#X_test_mm = mm.transform(X_test)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1,input_shape=(X.shape[1],), activation="sigmoid")                                
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer="sgd")

# %%
history = model.fit(X_train_ss,y_train,epochs=60)
# Out:
# Epoch 1/60
# 17/17 [==============================] - 0s 2ms/step - loss: 1.1576
# Epoch 2/60
# 17/17 [==============================] - 0s 1ms/step - loss: 1.0605
# Epoch 3/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.9667
# Epoch 4/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.9612
# Epoch 5/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.8853
# Epoch 6/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.8387
# Epoch 7/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7937
# Epoch 8/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.7821
# Epoch 9/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.7254
# Epoch 10/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.7171
# Epoch 11/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6824
# Epoch 12/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6618
# Epoch 13/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6499
# Epoch 14/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6238
# Epoch 15/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6206
# Epoch 16/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.6099
# Epoch 17/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5970
# Epoch 18/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5914
# Epoch 19/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5802
# Epoch 20/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5672
# Epoch 21/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5864
# Epoch 22/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5707
# Epoch 23/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5847
# Epoch 24/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5592
# Epoch 25/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5482
# Epoch 26/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5560
# Epoch 27/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5420
# Epoch 28/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5270
# Epoch 29/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5447
# Epoch 30/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5522
# Epoch 31/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5408
# Epoch 32/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4941
# Epoch 33/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5359
# Epoch 34/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5203
# Epoch 35/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5328
# Epoch 36/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5259
# Epoch 37/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5404
# Epoch 38/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5417
# Epoch 39/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5393
# Epoch 40/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5111
# Epoch 41/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5210
# Epoch 42/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5385
# Epoch 43/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5097
# Epoch 44/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5016
# Epoch 45/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5112
# Epoch 46/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5271
# Epoch 47/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5359
# Epoch 48/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4879
# Epoch 49/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4859
# Epoch 50/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5130
# Epoch 51/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5138
# Epoch 52/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4893
# Epoch 53/60
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5042
# Epoch 54/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5403
# Epoch 55/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4883
# Epoch 56/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4812
# Epoch 57/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5127
# Epoch 58/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5168
# Epoch 59/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5007
# Epoch 60/60
# 17/17 [==============================] - 0s 1ms/step - loss: 0.4641

# %%
plt.plot(history.history["loss"])

# %%
y_pred = model.predict(X_test_ss)

# %%
y_pred = np.where(y_pred >= 0.5, 1,0)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       146
#            1       0.77      0.60      0.68        85
#
#     accuracy                           0.79       231
#    macro avg       0.78      0.75      0.76       231
# weighted avg       0.79      0.79      0.78       231

# %% [markdown]
# <p><b>The score is not that good but we have try with single neuron, we can increase the score further by adding the layers, by chainging the activation function and optimizer, increasing/decreasing the epoch, etc.</b></p>
